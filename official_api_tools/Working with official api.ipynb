# %%
cd pathofexile/
# Out:
# /Users/steve/Programming/Path of Exile project/official_api_tools/pathofexile

# %%
import pathofexile.api as poe
import pathofexile.ladder as ladder
import sqlite3

# %%
cd ..
# Out:
# /Users/steve/Programming/Path of Exile project/official_api_tools

# %%
import poe_utils

reload(poe_utils)
# Out:
# <module 'poe_utils' from 'poe_utils.pyc'>

# %% [markdown]
# # Connect to an sqlite table

# %%
conn = sqlite3.connect('poe_races.db')
c = conn.cursor()

# %%
leagues = poe.get_leagues(league_type='season', season='Season10', compact_info=0, league_limit=1, league_offset=0)
print leagues[0].keys()
# Out:
# [u'startAt', u'description', u'registerAt', u'url', u'endAt', u'id', u'rules', u'event']

# %%
print leagues[0]
# Out:
# {u'startAt': u'2015-01-02T16:00:00Z', u'description': u'This is the Season Ten Signature Event.\n\nPlease check the Event Forums for more details and points awarded.', u'registerAt': u'2015-01-02T15:30:00Z', u'url': u'http://pathofexile.com/forum/view-thread/1156124', u'endAt': u'2015-01-02T17:30:00Z', u'id': u'90m Fixed Seed Brutal (S10S049)', u'rules': [{u'description': u'A character killed in Hardcore is moved to its parent league.', u'id': 4, u'name': u'Hardcore'}, {u'description': u'You may not party in this league.', u'id': 24, u'name': u'Solo'}], u'event': True}

# %%
poe_utils.all_leagues_to_table(c, conn, 'leagues')
conn.commit() # To actually push changes to the table
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2850
# 2900
# 2950
# 3000
# 3050
# 3100
# 3150
# 3200
# 3250
# 3300
# 3350
# 3400
# 3450
# 3500
# 3550
# 3600
# 3650
# 3700
# 3750
# 3800
# 3850
# 3900
# 3950
# 4000
# 4050
# 4100
# 4150
# 4200
# 4250
# 4300
# 4350
# 4400
# 4450
# 4500
# 4550
# 4600
# 4650
# 4700
# 4750
# 4800
# 4850
# 4900
# 4950
# 5000
# 5050
# 5100
# 5150
# 5200
# 5222

# %%
print c.execute('SELECT * FROM leagues')

# %%
league_ids = poe_utils.get_leagues_from_table(c,'leagues')
poe_utils.all_ladders_to_table(c, conn, league_ids, 'ladders', start=5222)
conn.commit()

# %%
league_ids = poe_utils.get_leagues_from_table(c,'leagues')
ladder1 = ladder.retrieve(league_ids[0])
ladder2 = ladder.retrieve(unicode(league_ids[3055]))

# %%
ladder1
# Out:
# [{u'account': {u'challenges': {u'total': 26},
#    u'name': u'Helman',
#    u'twitch': {u'name': u'helmannn'}},
#   u'character': {u'class': u'Duelist',
#    u'experience': 1501660,
#    u'level': 22,
#    u'name': u'Twitch_Tv___Helmannn'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 1},
#  {u'account': {u'challenges': {u'total': 36},
#    u'name': u'Morsexier',
#    u'twitch': {u'name': u'morsrageng'}},
#   u'character': {u'class': u'Marauder',
#    u'experience': 1463734,
#    u'level': 22,
#    u'name': u'ImFineEitherwayDickhead'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 2},
#  {u'account': {u'challenges': {u'total': 22}, u'name': u'Throzz'},
#   u'character': {u'class': u'Witch',
#    u'experience': 1462360,
#    u'level': 22,
#    u'name': u'Throzz_'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 3},
#  {u'account': {u'challenges': {u'total': 0},
#    u'name': u'cwu',
#    u'twitch': {u'name': u'comewithus'}},
#   u'character': {u'class': u'Templar',
#    u'experience': 1304147,
#    u'level': 22,
#    u'name': u'cwu_FORPOINTS'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 4},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'Rithz'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 1265850,
#    u'level': 22,
#    u'name': u'FUNRACESAREFUN'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 5},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'cobaIt'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 1185057,
#    u'level': 21,
#    u'name': u'CobaIt_'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 6},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'349528'},
#   u'character': {u'class': u'Templar',
#    u'experience': 1069025,
#    u'level': 21,
#    u'name': u'JQJHFZAILBTYIEEIEGVVBNM'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 7},
#  {u'account': {u'challenges': {u'total': 1},
#    u'name': u'SlixSC',
#    u'twitch': {u'name': u'slixsc'}},
#   u'character': {u'class': u'Ranger',
#    u'experience': 776487,
#    u'level': 19,
#    u'name': u'Slix_isRanged'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 8},
#  {u'account': {u'challenges': {u'total': 0},
#    u'name': u'johnnypr0x',
#    u'twitch': {u'name': u'johnnypr0x'}},
#   u'character': {u'class': u'Duelist',
#    u'experience': 742106,
#    u'level': 19,
#    u'name': u'johnnyhehehehehehehhehh'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 9},
#  {u'account': {u'challenges': {u'total': 38},
#    u'name': u'Swarox',
#    u'twitch': {u'name': u'swarox'}},
#   u'character': {u'class': u'Templar',
#    u'experience': 738454,
#    u'level': 19,
#    u'name': u'EndlessSwarox'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 10},
#  {u'account': {u'challenges': {u'total': 1},
#    u'name': u'Gr1m',
#    u'twitch': {u'name': u'gr1mtv'}},
#   u'character': {u'class': u'Duelist',
#    u'experience': 703847,
#    u'level': 19,
#    u'name': u'Mr_Bacon'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 11},
#  {u'account': {u'challenges': {u'total': 0},
#    u'name': u'HarryLarry',
#    u'twitch': {u'name': u'r_w_b'}},
#   u'character': {u'class': u'Marauder',
#    u'experience': 682068,
#    u'level': 18,
#    u'name': u'rrwwbb'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 12},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'bigskunk'},
#   u'character': {u'class': u'Templar',
#    u'experience': 676441,
#    u'level': 18,
#    u'name': u'cantkeepmypantson'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 13},
#  {u'account': {u'challenges': {u'total': 0},
#    u'name': u'Varanice',
#    u'twitch': {u'name': u'varanice'}},
#   u'character': {u'class': u'Witch',
#    u'experience': 666585,
#    u'level': 18,
#    u'name': u'WitchRaceIsThis'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 14},
#  {u'account': {u'challenges': {u'total': 5}, u'name': u'crazypyro'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 657635,
#    u'level': 18,
#    u'name': u'CrazypyroooSwag'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 15},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'dknight'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 562447,
#    u'level': 18,
#    u'name': u'DathCXXXIsolo'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 16},
#  {u'account': {u'challenges': {u'total': 4},
#    u'name': u'metagross',
#    u'twitch': {u'name': u'someguywhoplaysgames'}},
#   u'character': {u'class': u'Duelist',
#    u'experience': 543061,
#    u'level': 17,
#    u'name': u'someooguyy'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 17},
#  {u'account': {u'challenges': {u'total': 10},
#    u'name': u'StimpsonH',
#    u'twitch': {u'name': u'stimpsonh'}},
#   u'character': {u'class': u'Marauder',
#    u'experience': 505215,
#    u'level': 17,
#    u'name': u'ScionIsMyWaifu'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 18},
#  {u'account': {u'challenges': {u'total': 1}, u'name': u'bizor87'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 492744,
#    u'level': 17,
#    u'name': u'rtzkrtzkrtzk'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 19},
#  {u'account': {u'challenges': {u'total': 0},
#    u'name': u'PureLaine',
#    u'twitch': {u'name': u'purelainex'}},
#   u'character': {u'class': u'Ranger',
#    u'experience': 489992,
#    u'level': 17,
#    u'name': u'eredsdfgggggggggggggggg'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 20},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'HandsomeBear'},
#   u'character': {u'class': u'Witch',
#    u'experience': 477815,
#    u'level': 17,
#    u'name': u'CoolTheEffDown'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 21},
#  {u'account': {u'challenges': {u'total': 0},
#    u'name': u'Triela',
#    u'twitch': {u'name': u'yosshie'}},
#   u'character': {u'class': u'Shadow',
#    u'experience': 477642,
#    u'level': 17,
#    u'name': u'TrielaRaceAIP'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 22},
#  {u'account': {u'challenges': {u'total': 0},
#    u'name': u'WhosYourDaddy',
#    u'twitch': {u'name': u'drg_mvp'}},
#   u'character': {u'class': u'Witch',
#    u'experience': 467679,
#    u'level': 17,
#    u'name': u'Ah_hahaha_ha'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 23},
#  {u'account': {u'challenges': {u'total': 36}, u'name': u'machine5'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 465857,
#    u'level': 17,
#    u'name': u'rabbitAIparty'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 24},
#  {u'account': {u'challenges': {u'total': 8}, u'name': u'shcmlhy'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 464417,
#    u'level': 17,
#    u'name': u'IamaDumplar'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 25},
#  {u'account': {u'challenges': {u'total': 5}, u'name': u'tqp'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 456381,
#    u'level': 17,
#    u'name': u'partyracebest'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 26},
#  {u'account': {u'challenges': {u'total': 18},
#    u'name': u'crazeuk',
#    u'twitch': {u'name': u'crazeuk121'}},
#   u'character': {u'class': u'Ranger',
#    u'experience': 453590,
#    u'level': 17,
#    u'name': u'CrazeRace'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 27},
#  {u'account': {u'challenges': {u'total': 1}, u'name': u'dot_1'},
#   u'character': {u'class': u'Templar',
#    u'experience': 451558,
#    u'level': 17,
#    u'name': u'KaliJuga'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 28},
#  {u'account': {u'challenges': {u'total': 37}, u'name': u'Archimedius'},
#   u'character': {u'class': u'Templar',
#    u'experience': 434586,
#    u'level': 16,
#    u'name': u'HourLong'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 29},
#  {u'account': {u'challenges': {u'total': 20}, u'name': u'Gregorius'},
#   u'character': {u'class': u'Witch',
#    u'experience': 428574,
#    u'level': 16,
#    u'name': u'DesyncIsTheLimit'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 30},
#  {u'account': {u'challenges': {u'total': 37}, u'name': u'whrsmycoffee'},
#   u'character': {u'class': u'Marauder',
#    u'experience': 416700,
#    u'level': 16,
#    u'name': u'CupOfWin'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 31},
#  {u'account': {u'challenges': {u'total': 36}, u'name': u'Erdoganas'},
#   u'character': {u'class': u'Templar',
#    u'experience': 403847,
#    u'level': 16,
#    u'name': u'ErdoFireThingyWithTotem'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 32},
#  {u'account': {u'challenges': {u'total': 28},
#    u'name': u'Johnny_Annihilation',
#    u'twitch': {u'name': u'yor0'}},
#   u'character': {u'class': u'Shadow',
#    u'experience': 385463,
#    u'level': 16,
#    u'name': u'Fire_Arrow_Poison_Trap'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 33},
#  {u'account': {u'challenges': {u'total': 17}, u'name': u'MrFlashcat'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 384834,
#    u'level': 16,
#    u'name': u'MrCleavecat'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 34},
#  {u'account': {u'challenges': {u'total': 1},
#    u'name': u'unsane',
#    u'twitch': {u'name': u'unsane'}},
#   u'character': {u'class': u'Marauder',
#    u'experience': 356004,
#    u'level': 16,
#    u'name': u'Pas_de_Panique'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 35},
#  {u'account': {u'challenges': {u'total': 14}, u'name': u'Schmeelk'},
#   u'character': {u'class': u'Marauder',
#    u'experience': 355902,
#    u'level': 16,
#    u'name': u'Idontknowwhatimgoingto'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 36},
#  {u'account': {u'challenges': {u'total': 27},
#    u'name': u'Floytesangen',
#    u'twitch': {u'name': u'floytesangen'}},
#   u'character': {u'class': u'Shadow',
#    u'experience': 354304,
#    u'level': 16,
#    u'name': u'apoolboywhoismexican'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 37},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'Joelzy'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 350459,
#    u'level': 16,
#    u'name': u'zergmoarree'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 38},
#  {u'account': {u'challenges': {u'total': 6}, u'name': u'Karauna'},
#   u'character': {u'class': u'Templar',
#    u'experience': 348716,
#    u'level': 16,
#    u'name': u'MacheteSteve'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 39},
#  {u'account': {u'challenges': {u'total': 36},
#    u'name': u'Hybriis',
#    u'twitch': {u'name': u'hybriss'}},
#   u'character': {u'class': u'Duelist',
#    u'experience': 330104,
#    u'level': 15,
#    u'name': u'HelmansBackup'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 40},
#  {u'account': {u'challenges': {u'total': 19}, u'name': u'nheowitzki'},
#   u'character': {u'class': u'Witch',
#    u'experience': 322123,
#    u'level': 15,
#    u'name': u'NeedMoarPoints_____'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 41},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'witch75'},
#   u'character': {u'class': u'Marauder',
#    u'experience': 317185,
#    u'level': 15,
#    u'name': u'ScionOfFuckingKalandra'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 42},
#  {u'account': {u'challenges': {u'total': 27}, u'name': u'SigmaPi'},
#   u'character': {u'class': u'Templar',
#    u'experience': 297734,
#    u'level': 15,
#    u'name': u'AFK_NOVA'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 43},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'skoek'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 294192,
#    u'level': 15,
#    u'name': u'EHC'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 44},
#  {u'account': {u'challenges': {u'total': 15}, u'name': u'superlocky'},
#   u'character': {u'class': u'Templar',
#    u'experience': 292047,
#    u'level': 15,
#    u'name': u'__________________P'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 45},
#  {u'account': {u'challenges': {u'total': 24},
#    u'name': u'Bahriel',
#    u'twitch': {u'name': u'bahriel'}},
#   u'character': {u'class': u'Witch',
#    u'experience': 263067,
#    u'level': 14,
#    u'name': u'Obleviae'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 46},
#  {u'account': {u'challenges': {u'total': 27}, u'name': u'epp_'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 260197,
#    u'level': 14,
#    u'name': u'BURNIINGNIQUA_II'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 47},
#  {u'account': {u'challenges': {u'total': 0},
#    u'name': u'bitspirit',
#    u'twitch': {u'name': u'festyrbg'}},
#   u'character': {u'class': u'Shadow',
#    u'experience': 251184,
#    u'level': 14,
#    u'name': u'FestyrRR__'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 48},
#  {u'account': {u'challenges': {u'total': 40}, u'name': u'ALong'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 247884,
#    u'level': 14,
#    u'name': u'fsdfasfsdf'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 49},
#  {u'account': {u'challenges': {u'total': 31},
#    u'name': u'SmokinTumbleWeed',
#    u'twitch': {u'name': u'smokintumbleweed'}},
#   u'character': {u'class': u'Marauder',
#    u'experience': 245137,
#    u'level': 14,
#    u'name': u'MenoraManOfWraeclast'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 50},
#  {u'account': {u'challenges': {u'total': 10}, u'name': u'TheJedipimp'},
#   u'character': {u'class': u'Templar',
#    u'experience': 244055,
#    u'level': 14,
#    u'name': u'JedipimpRacing'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 51},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'Tesshinxd'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 241147,
#    u'level': 14,
#    u'name': u'AIpartyTox'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 52},
#  {u'account': {u'challenges': {u'total': 12}, u'name': u'greenyadzer'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 235986,
#    u'level': 14,
#    u'name': u'Lexxero'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 53},
#  {u'account': {u'challenges': {u'total': 36},
#    u'name': u'BLOODSETE',
#    u'twitch': {u'name': u'samtuga13'}},
#   u'character': {u'class': u'Ranger',
#    u'experience': 232847,
#    u'level': 14,
#    u'name': u'jon_ripipi'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 54},
#  {u'account': {u'challenges': {u'total': 36},
#    u'name': u'vidlak666',
#    u'twitch': {u'name': u'vidlak666'}},
#   u'character': {u'class': u'Ranger',
#    u'experience': 231512,
#    u'level': 14,
#    u'name': u'VypichnuTiOci'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 55},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'ming_15'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 231191,
#    u'level': 14,
#    u'name': u'CleanWindows'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 56},
#  {u'account': {u'challenges': {u'total': 36},
#    u'name': u'seepah',
#    u'twitch': {u'name': u'seepah'}},
#   u'character': {u'class': u'Ranger',
#    u'experience': 229660,
#    u'level': 14,
#    u'name': u'seepah_AIlove_desu'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 57},
#  {u'account': {u'challenges': {u'total': 36}, u'name': u'Uvne'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 216305,
#    u'level': 14,
#    u'name': u'hamscentolamination'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 58},
#  {u'account': {u'challenges': {u'total': 0},
#    u'name': u'4EverLost',
#    u'twitch': {u'name': u'4everlost'}},
#   u'character': {u'class': u'Duelist',
#    u'experience': 215161,
#    u'level': 14,
#    u'name': u'RaceTime_I'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 59},
#  {u'account': {u'challenges': {u'total': 12},
#    u'name': u'Equilibrium87',
#    u'twitch': {u'name': u'equilibrium87'}},
#   u'character': {u'class': u'Duelist',
#    u'experience': 214426,
#    u'level': 14,
#    u'name': u'zzzzzz___'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 60},
#  {u'account': {u'challenges': {u'total': 1}, u'name': u'Aeben'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 214370,
#    u'level': 14,
#    u'name': u'sHADOWsPRINKLESZZ'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 61},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'krackin13'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 212336,
#    u'level': 14,
#    u'name': u'Dumbass_Fucker____'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 62},
#  {u'account': {u'challenges': {u'total': 17}, u'name': u'SchoeneKuh'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 211797,
#    u'level': 14,
#    u'name': u'AbgehHans'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 63},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'nasty5651'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 211789,
#    u'level': 14,
#    u'name': u'reererrea'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 64},
#  {u'account': {u'challenges': {u'total': 36},
#    u'name': u'Omiom',
#    u'twitch': {u'name': u'omiomnomnom'}},
#   u'character': {u'class': u'Duelist',
#    u'experience': 210095,
#    u'level': 14,
#    u'name': u'Solo_Yolo_Like_A_Cholo'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 65},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'Fackelyo'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 201122,
#    u'level': 13,
#    u'name': u'sebiistkacke'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 66},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'Skystrider'},
#   u'character': {u'class': u'Witch',
#    u'experience': 200611,
#    u'level': 13,
#    u'name': u'Shirlexace'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 67},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'thealah'},
#   u'character': {u'class': u'Marauder',
#    u'experience': 199130,
#    u'level': 13,
#    u'name': u'Scenz'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 68},
#  {u'account': {u'challenges': {u'total': 28}, u'name': u'charlie79'},
#   u'character': {u'class': u'Witch',
#    u'experience': 196822,
#    u'level': 13,
#    u'name': u'_Samantha_'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 69},
#  {u'account': {u'challenges': {u'total': 24}, u'name': u'Mishima_jp'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 195185,
#    u'level': 13,
#    u'name': u'gafgha'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 70},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'shumped'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 189279,
#    u'level': 13,
#    u'name': u'CleanaKills'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 71},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'MixedHerb'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 188380,
#    u'level': 13,
#    u'name': u'PAPASgonnaFUCKya'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 72},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'EleXhender'},
#   u'character': {u'class': u'Witch',
#    u'experience': 186624,
#    u'level': 13,
#    u'name': u'HopeIWinAI'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 73},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'Katakiri'},
#   u'character': {u'class': u'Witch',
#    u'experience': 185022,
#    u'level': 13,
#    u'name': u'ytdyryyadaw'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 74},
#  {u'account': {u'challenges': {u'total': 37}, u'name': u'whitt342'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 179163,
#    u'level': 13,
#    u'name': u'NoDeathsThisTime'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 75},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'joker__4ever'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 178409,
#    u'level': 13,
#    u'name': u'anusanusanusanusanus'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 76},
#  {u'account': {u'challenges': {u'total': 30}, u'name': u'FunEU'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 176895,
#    u'level': 13,
#    u'name': u'funeuntresun'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 77},
#  {u'account': {u'challenges': {u'total': 14}, u'name': u'dole1593'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 172603,
#    u'level': 13,
#    u'name': u'DoleRacer'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 78},
#  {u'account': {u'challenges': {u'total': 28},
#    u'name': u'wegebah',
#    u'twitch': {u'name': u'wegebah'}},
#   u'character': {u'class': u'Witch',
#    u'experience': 171014,
#    u'level': 13,
#    u'name': u'GG_WegeRacingWitch'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 79},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'mercviper'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 170447,
#    u'level': 13,
#    u'name': u'Aylerna'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 80},
#  {u'account': {u'challenges': {u'total': 36},
#    u'name': u'Cazman',
#    u'twitch': {u'name': u'cazmarran'}},
#   u'character': {u'class': u'Templar',
#    u'experience': 165478,
#    u'level': 13,
#    u'name': u'Fuckinracebitch'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 81},
#  {u'account': {u'challenges': {u'total': 16}, u'name': u'JohtoKin'},
#   u'character': {u'class': u'Templar',
#    u'experience': 164895,
#    u'level': 13,
#    u'name': u'NoIDontLikeFaceHuggers'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 82},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'swordly'},
#   u'character': {u'class': u'Witch',
#    u'experience': 158483,
#    u'level': 13,
#    u'name': u'racesolomajo'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 83},
#  {u'account': {u'challenges': {u'total': 16},
#    u'name': u'kannibalz',
#    u'twitch': {u'name': u'kannibalz'}},
#   u'character': {u'class': u'Shadow',
#    u'experience': 158091,
#    u'level': 13,
#    u'name': u'mywillyiswolly'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 84},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'AdanOfDarkmoon'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 154658,
#    u'level': 12,
#    u'name': u'CopperyTang'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 85},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'MouseNorr'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 154564,
#    u'level': 12,
#    u'name': u'Sariushdezz'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 86},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'politibilen'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 154324,
#    u'level': 12,
#    u'name': u'hyggerace'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 87},
#  {u'account': {u'challenges': {u'total': 9},
#    u'name': u'autechy',
#    u'twitch': {u'name': u'autechy'}},
#   u'character': {u'class': u'Shadow',
#    u'experience': 151469,
#    u'level': 12,
#    u'name': u'auteciuhq'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 88},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'RhioTre'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 151016,
#    u'level': 12,
#    u'name': u'Ilya_Kuryakin'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 89},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'NannaFudge'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 149726,
#    u'level': 12,
#    u'name': u'PhreakLovesTonsOfDamage'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 90},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'noxepman'},
#   u'character': {u'class': u'Witch',
#    u'experience': 143367,
#    u'level': 12,
#    u'name': u'dfgdfgdsfh'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 91},
#  {u'account': {u'challenges': {u'total': 36}, u'name': u'Ironskies'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 140972,
#    u'level': 12,
#    u'name': u'Panrai'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 92},
#  {u'account': {u'challenges': {u'total': 36}, u'name': u'Emerl'},
#   u'character': {u'class': u'Witch',
#    u'experience': 140171,
#    u'level': 12,
#    u'name': u'pewpewanu'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 93},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'val5'},
#   u'character': {u'class': u'Marauder',
#    u'experience': 140082,
#    u'level': 12,
#    u'name': u'HuepfHuep_f'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 94},
#  {u'account': {u'challenges': {u'total': 16}, u'name': u'Shaosh'},
#   u'character': {u'class': u'Marauder',
#    u'experience': 139771,
#    u'level': 12,
#    u'name': u'Zahnluecke'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 95},
#  {u'account': {u'challenges': {u'total': 24}, u'name': u'Jaerbi'},
#   u'character': {u'class': u'Witch',
#    u'experience': 139041,
#    u'level': 12,
#    u'name': u'JaerbiWitch'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 96},
#  {u'account': {u'challenges': {u'total': 36},
#    u'name': u'likelol',
#    u'twitch': {u'name': u'just75th'}},
#   u'character': {u'class': u'Duelist',
#    u'experience': 138837,
#    u'level': 12,
#    u'name': u'Just_PEWPEWPEWPEW'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 97},
#  {u'account': {u'challenges': {u'total': 12},
#    u'name': u'drunkensnake',
#    u'twitch': {u'name': u'drunkensnake'}},
#   u'character': {u'class': u'Duelist',
#    u'experience': 137138,
#    u'level': 12,
#    u'name': u'fghjfghjhfgjhfgjfgj'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 98},
#  {u'account': {u'challenges': {u'total': 16}, u'name': u'Exraven'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 136569,
#    u'level': 12,
#    u'name': u'Solo_Raven'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 99},
#  {u'account': {u'challenges': {u'total': 1}, u'name': u'Lukulus'},
#   u'character': {u'class': u'Witch',
#    u'experience': 136113,
#    u'level': 12,
#    u'name': u'sesesese'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 100},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'jorbeee'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 133851,
#    u'level': 12,
#    u'name': u'Jussinkivekset'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 101},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'Juskii'},
#   u'character': {u'class': u'Marauder',
#    u'experience': 132572,
#    u'level': 12,
#    u'name': u'nuunuuu'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 102},
#  {u'account': {u'challenges': {u'total': 5},
#    u'name': u'GreenDude',
#    u'twitch': {u'name': u'greendudehc'}},
#   u'character': {u'class': u'Shadow',
#    u'experience': 129167,
#    u'level': 12,
#    u'name': u'_GreenDude_'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 103},
#  {u'account': {u'challenges': {u'total': 9}, u'name': u'Pe4ceM4ker'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 128926,
#    u'level': 12,
#    u'name': u'aaaaaaaaaaafedfdfdfd'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 104},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'rCRO'},
#   u'character': {u'class': u'Templar',
#    u'experience': 128727,
#    u'level': 12,
#    u'name': u'rCROracernjabdva'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 105},
#  {u'account': {u'challenges': {u'total': 0},
#    u'name': u'Repsi',
#    u'twitch': {u'name': u'tucnak2'}},
#   u'character': {u'class': u'Marauder',
#    u'experience': 127789,
#    u'level': 12,
#    u'name': u'qweqwetkg'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 106},
#  {u'account': {u'challenges': {u'total': 6}, u'name': u'thecleansanchez'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 127714,
#    u'level': 12,
#    u'name': u'ouchthatssharppppp'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 107},
#  {u'account': {u'challenges': {u'total': 6}, u'name': u'basicen'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 126583,
#    u'level': 12,
#    u'name': u'IMLATEBROS'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 108},
#  {u'account': {u'challenges': {u'total': 6}, u'name': u'Jack89'},
#   u'character': {u'class': u'Witch',
#    u'experience': 123866,
#    u'level': 12,
#    u'name': u'kkksassasa'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 109},
#  {u'account': {u'challenges': {u'total': 40}, u'name': u'Leioblastus'},
#   u'character': {u'class': u'Witch',
#    u'experience': 122859,
#    u'level': 12,
#    u'name': u'_Mtilo'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 110},
#  {u'account': {u'challenges': {u'total': 13}, u'name': u'IXTryHardXI'},
#   u'character': {u'class': u'Templar',
#    u'experience': 122406,
#    u'level': 12,
#    u'name': u'Racin__Time'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 111},
#  {u'account': {u'challenges': {u'total': 21}, u'name': u'Kladroun'},
#   u'character': {u'class': u'Witch',
#    u'experience': 122349,
#    u'level': 12,
#    u'name': u'KlokKake'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 112},
#  {u'account': {u'challenges': {u'total': 26}, u'name': u'DnAngel'},
#   u'character': {u'class': u'Templar',
#    u'experience': 122275,
#    u'level': 12,
#    u'name': u'PrysmatyK'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 113},
#  {u'account': {u'challenges': {u'total': 37}, u'name': u'jechkaar'},
#   u'character': {u'class': u'Marauder',
#    u'experience': 122048,
#    u'level': 12,
#    u'name': u'jechkaaaar'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 114},
#  {u'account': {u'challenges': {u'total': 9}, u'name': u'Cexopher'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 121433,
#    u'level': 12,
#    u'name': u'solocex'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 115},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'waag42'},
#   u'character': {u'class': u'Templar',
#    u'experience': 120379,
#    u'level': 12,
#    u'name': u'tippomont'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 116},
#  {u'account': {u'challenges': {u'total': 0},
#    u'name': u'Laturi',
#    u'twitch': {u'name': u'laturi'}},
#   u'character': {u'class': u'Shadow',
#    u'experience': 119680,
#    u'level': 12,
#    u'name': u'Laturi_gudjnsj'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 117},
#  {u'account': {u'challenges': {u'total': 11}, u'name': u'Ixo'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 119480,
#    u'level': 12,
#    u'name': u'IxoX'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 118},
#  {u'account': {u'challenges': {u'total': 40}, u'name': u'Duster66'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 119198,
#    u'level': 12,
#    u'name': u'Dsty'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 119},
#  {u'account': {u'challenges': {u'total': 4}, u'name': u'MadRussian'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 118983,
#    u'level': 12,
#    u'name': u'Khannnnnnnnnnnnnnnnnnnn'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 120},
#  {u'account': {u'challenges': {u'total': 12}, u'name': u'goblyn'},
#   u'character': {u'class': u'Witch',
#    u'experience': 118385,
#    u'level': 12,
#    u'name': u'rewtds'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 121},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'fruitybooty'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 117932,
#    u'level': 12,
#    u'name': u'Krunkpparrian'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 122},
#  {u'account': {u'challenges': {u'total': 24}, u'name': u'MrBlind01'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 116148,
#    u'level': 11,
#    u'name': u'segfsefsdfsaf'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 123},
#  {u'account': {u'challenges': {u'total': 26}, u'name': u'Booply'},
#   u'character': {u'class': u'Templar',
#    u'experience': 115054,
#    u'level': 11,
#    u'name': u'Sillybastahds'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 124},
#  {u'account': {u'challenges': {u'total': 27}, u'name': u'mickey0212'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 114219,
#    u'level': 11,
#    u'name': u'HelloSexyPeople'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 125},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'ShadowYoshi'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 113678,
#    u'level': 11,
#    u'name': u'fdwafqfqwfwq'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 126},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'GRiMSKuLL'},
#   u'character': {u'class': u'Templar',
#    u'experience': 113479,
#    u'level': 11,
#    u'name': u'AA_BRoW_X'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 127},
#  {u'account': {u'challenges': {u'total': 25}, u'name': u'kapkapkap'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 108661,
#    u'level': 11,
#    u'name': u'cacadedure'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 128},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'Oudeis'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 104091,
#    u'level': 11,
#    u'name': u'Unasecgendlic'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 129},
#  {u'account': {u'challenges': {u'total': 10}, u'name': u'IppoMakunouchi'},
#   u'character': {u'class': u'Marauder',
#    u'experience': 103051,
#    u'level': 11,
#    u'name': u'RacingRyuIsHOTandTotemy'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 130},
#  {u'account': {u'challenges': {u'total': 12},
#    u'name': u'Portent',
#    u'twitch': {u'name': u'portentna'}},
#   u'character': {u'class': u'Ranger',
#    u'experience': 102370,
#    u'level': 11,
#    u'name': u'NothingToBananaAbout'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 131},
#  {u'account': {u'challenges': {u'total': 9}, u'name': u'Moostache'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 100029,
#    u'level': 11,
#    u'name': u'MoostacheAI'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 132},
#  {u'account': {u'challenges': {u'total': 36}, u'name': u'McThuggerson'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 98879,
#    u'level': 11,
#    u'name': u'DumpsterBait'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 133},
#  {u'account': {u'challenges': {u'total': 7}, u'name': u'Hanatsu'},
#   u'character': {u'class': u'Witch',
#    u'experience': 97596,
#    u'level': 11,
#    u'name': u'Fox_pewpewsolo'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 134},
#  {u'account': {u'challenges': {u'total': 5}, u'name': u'Mysterio85'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 97230,
#    u'level': 11,
#    u'name': u'Cerealkillahh'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 135},
#  {u'account': {u'challenges': {u'total': 25}, u'name': u'GasparTomas'},
#   u'character': {u'class': u'Marauder',
#    u'experience': 96334,
#    u'level': 11,
#    u'name': u'feqwfwerfqe'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 136},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'Psalmin'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 95163,
#    u'level': 11,
#    u'name': u'TrapAlotPsalmin'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 137},
#  {u'account': {u'challenges': {u'total': 36}, u'name': u'Caipirinha'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 94196,
#    u'level': 11,
#    u'name': u'_Frikadelle_'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 138},
#  {u'account': {u'challenges': {u'total': 36}, u'name': u'crackedsash'},
#   u'character': {u'class': u'Marauder',
#    u'experience': 93639,
#    u'level': 11,
#    u'name': u'_Bratkartoffeln_'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 139},
#  {u'account': {u'challenges': {u'total': 36}, u'name': u'Fightgarr'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 93446,
#    u'level': 11,
#    u'name': u'dfhdfhdfhdfhhhhh'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 140},
#  {u'account': {u'challenges': {u'total': 12},
#    u'name': u'Geldric',
#    u'twitch': {u'name': u'geldricpoe'}},
#   u'character': {u'class': u'Ranger',
#    u'experience': 92957,
#    u'level': 11,
#    u'name': u'Geldric_Delme_I'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 141},
#  {u'account': {u'challenges': {u'total': 19}, u'name': u'bazoungus'},
#   u'character': {u'class': u'Witch',
#    u'experience': 92696,
#    u'level': 11,
#    u'name': u'chrombanec'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 142},
#  {u'account': {u'challenges': {u'total': 14}, u'name': u'NeoElla'},
#   u'character': {u'class': u'Witch',
#    u'experience': 92618,
#    u'level': 11,
#    u'name': u'AIWitcho'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 143},
#  {u'account': {u'challenges': {u'total': 30}, u'name': u'Lionotus'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 89542,
#    u'level': 11,
#    u'name': u'RKCAE'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 144},
#  {u'account': {u'challenges': {u'total': 13}, u'name': u'AnotherGloriousDawn'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 88285,
#    u'level': 11,
#    u'name': u'Blumpstar'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 145},
#  {u'account': {u'challenges': {u'total': 5}, u'name': u'jol_07'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 87603,
#    u'level': 11,
#    u'name': u'correeemazzz'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 146},
#  {u'account': {u'challenges': {u'total': 31}, u'name': u'Rizla_x'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 86818,
#    u'level': 11,
#    u'name': u'notRizla'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 147},
#  {u'account': {u'challenges': {u'total': 0},
#    u'name': u'prettyboy',
#    u'twitch': {u'name': u'prettyboy0926'}},
#   u'character': {u'class': u'Duelist',
#    u'experience': 85125,
#    u'level': 10,
#    u'name': u'MYNameIsRJ'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 148},
#  {u'account': {u'challenges': {u'total': 32}, u'name': u'HeavyR'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 84331,
#    u'level': 10,
#    u'name': u'angryinches'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 149},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'IAmThePacMan'},
#   u'character': {u'class': u'Witch',
#    u'experience': 83775,
#    u'level': 10,
#    u'name': u'TimeToSlaySomePoos'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 150},
#  {u'account': {u'challenges': {u'total': 7}, u'name': u'Iinventedhats'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 83688,
#    u'level': 10,
#    u'name': u'ooooookay'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 151},
#  {u'account': {u'challenges': {u'total': 7}, u'name': u'TeiPei'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 82461,
#    u'level': 10,
#    u'name': u'TeiPei_SecondRace'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 152},
#  {u'account': {u'challenges': {u'total': 0},
#    u'name': u'Ogre669',
#    u'twitch': {u'name': u'ogre669'}},
#   u'character': {u'class': u'Ranger',
#    u'experience': 82118,
#    u'level': 10,
#    u'name': u'FrozenBoogerFlipper'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 153},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'fuisy'},
#   u'character': {u'class': u'Witch',
#    u'experience': 80864,
#    u'level': 10,
#    u'name': u'FuisyWE'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 154},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'mckers'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 80215,
#    u'level': 10,
#    u'name': u'Tolans_Darkwood_Bracer'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 155},
#  {u'account': {u'challenges': {u'total': 36}, u'name': u'sinisterhatter'},
#   u'character': {u'class': u'Templar',
#    u'experience': 79668,
#    u'level': 10,
#    u'name': u'TEmponTheTampon'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 156},
#  {u'account': {u'challenges': {u'total': 10}, u'name': u'MrProBowl'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 79592,
#    u'level': 10,
#    u'name': u'Reachforthesky'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 157},
#  {u'account': {u'challenges': {u'total': 10}, u'name': u'Lungomono'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 78676,
#    u'level': 10,
#    u'name': u'YetAnOtherSlashers'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 158},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'Ohvolo'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 78342,
#    u'level': 10,
#    u'name': u'Shvolo'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 159},
#  {u'account': {u'challenges': {u'total': 36}, u'name': u'jacobtoye'},
#   u'character': {u'class': u'Witch',
#    u'experience': 78066,
#    u'level': 10,
#    u'name': u'LupusRaceOneThreeOne'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 160},
#  {u'account': {u'challenges': {u'total': 4}, u'name': u'Aglargon'},
#   u'character': {u'class': u'Marauder',
#    u'experience': 78063,
#    u'level': 10,
#    u'name': u'RIP_Tornado'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 161},
#  {u'account': {u'challenges': {u'total': 37},
#    u'name': u'Fobes',
#    u'twitch': {u'name': u'mrfobes'}},
#   u'character': {u'class': u'Marauder',
#    u'experience': 78025,
#    u'level': 10,
#    u'name': u'Martegno'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 162},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'r4nsom'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 77477,
#    u'level': 10,
#    u'name': u'yjtjtyjt'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 163},
#  {u'account': {u'challenges': {u'total': 0},
#    u'name': u'ctamblyn',
#    u'twitch': {u'name': u'ctamblyn'}},
#   u'character': {u'class': u'Duelist',
#    u'experience': 76776,
#    u'level': 10,
#    u'name': u'BC_C'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 164},
#  {u'account': {u'challenges': {u'total': 22}, u'name': u'PhoenixFury77'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 75592,
#    u'level': 10,
#    u'name': u'Phoenixmain'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 165},
#  {u'account': {u'challenges': {u'total': 7}, u'name': u'Black_Street'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 75165,
#    u'level': 10,
#    u'name': u'Nurety'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 166},
#  {u'account': {u'challenges': {u'total': 23},
#    u'name': u'Bodacious3369',
#    u'twitch': {u'name': u'bodacious3369'}},
#   u'character': {u'class': u'Duelist',
#    u'experience': 74076,
#    u'level': 10,
#    u'name': u'DuelistForRace'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 167},
#  {u'account': {u'challenges': {u'total': 36}, u'name': u'slably'},
#   u'character': {u'class': u'Marauder',
#    u'experience': 74025,
#    u'level': 10,
#    u'name': u'StinkyMinor'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 168},
#  {u'account': {u'challenges': {u'total': 4}, u'name': u'gabbat'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 73927,
#    u'level': 10,
#    u'name': u'a_few_points'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 169},
#  {u'account': {u'challenges': {u'total': 12}, u'name': u'tickmanfan'},
#   u'character': {u'class': u'Templar',
#    u'experience': 72225,
#    u'level': 10,
#    u'name': u'SomeoneSetMyPoopOnFire'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 170},
#  {u'account': {u'challenges': {u'total': 2},
#    u'name': u'Squiggles150',
#    u'twitch': {u'name': u'squigglesstarcraft'}},
#   u'character': {u'class': u'Templar',
#    u'experience': 72108,
#    u'level': 10,
#    u'name': u'squiggsracer'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 171},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'KingGreen'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 72012,
#    u'level': 10,
#    u'name': u'FastestManEU'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 172},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'Almagestum'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 69822,
#    u'level': 10,
#    u'name': u'Almagest'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 173},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'Grindtroll'},
#   u'character': {u'class': u'Templar',
#    u'experience': 69294,
#    u'level': 10,
#    u'name': u'GrindPeluken'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 174},
#  {u'account': {u'challenges': {u'total': 0},
#    u'name': u'SickScars',
#    u'twitch': {u'name': u'setoarm'}},
#   u'character': {u'class': u'Marauder',
#    u'experience': 67992,
#    u'level': 10,
#    u'name': u'SetoLovesLeapslamming'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 175},
#  {u'account': {u'challenges': {u'total': 0},
#    u'name': u'BebopDeluxe',
#    u'twitch': {u'name': u'doodooranger'}},
#   u'character': {u'class': u'Templar',
#    u'experience': 67415,
#    u'level': 10,
#    u'name': u'DooDooTraps'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 176},
#  {u'account': {u'challenges': {u'total': 6}, u'name': u'BraveZero'},
#   u'character': {u'class': u'Witch',
#    u'experience': 66345,
#    u'level': 10,
#    u'name': u'YarDarHarMar'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 177},
#  {u'account': {u'challenges': {u'total': 7},
#    u'name': u'purebishop',
#    u'twitch': {u'name': u'kevinforgot'}},
#   u'character': {u'class': u'Duelist',
#    u'experience': 64324,
#    u'level': 10,
#    u'name': u'TheChefsKnife'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 178},
#  {u'account': {u'challenges': {u'total': 16},
#    u'name': u'Osorezu',
#    u'twitch': {u'name': u'osorezu'}},
#   u'character': {u'class': u'Marauder',
#    u'experience': 63386,
#    u'level': 10,
#    u'name': u'Wrath_Mauls'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 179},
#  {u'account': {u'challenges': {u'total': 16}, u'name': u'asdfdrew'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 61762,
#    u'level': 10,
#    u'name': u'xsprcryzx'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 180},
#  {u'account': {u'challenges': {u'total': 19}, u'name': u'vraniel'},
#   u'character': {u'class': u'Templar',
#    u'experience': 61744,
#    u'level': 10,
#    u'name': u'garigariarar'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 181},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'markKKram'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 60913,
#    u'level': 9,
#    u'name': u'Endualist'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 182},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'Mummah'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 59626,
#    u'level': 9,
#    u'name': u'CLDLY_LETme_JOIN_you'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 183},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'dnbard'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 59378,
#    u'level': 9,
#    u'name': u'Velasque'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 184},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'Mechowa'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 59009,
#    u'level': 9,
#    u'name': u'Boo_Boxxy'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 185},
#  {u'account': {u'challenges': {u'total': 25}, u'name': u'Angstklinge'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 58822,
#    u'level': 9,
#    u'name': u'BlaBlaBlaBlubBlub'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 186},
#  {u'account': {u'challenges': {u'total': 18}, u'name': u'Interfector'},
#   u'character': {u'class': u'Marauder',
#    u'experience': 57813,
#    u'level': 9,
#    u'name': u'IDrinkFireWater'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 187},
#  {u'account': {u'challenges': {u'total': 7}, u'name': u'Naeshar'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 57564,
#    u'level': 9,
#    u'name': u'Esqess'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 188},
#  {u'account': {u'challenges': {u'total': 0},
#    u'name': u'Jagex',
#    u'twitch': {u'name': u'saggiest'}},
#   u'character': {u'class': u'Witch',
#    u'experience': 57476,
#    u'level': 9,
#    u'name': u'KonyAllOverYou'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 189},
#  {u'account': {u'challenges': {u'total': 27}, u'name': u'labile'},
#   u'character': {u'class': u'Marauder',
#    u'experience': 57453,
#    u'level': 9,
#    u'name': u'labile__'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 190},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'boul97419'},
#   u'character': {u'class': u'Witch',
#    u'experience': 57424,
#    u'level': 9,
#    u'name': u'GIGOGIGII'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 191},
#  {u'account': {u'challenges': {u'total': 0},
#    u'name': u'cloudily',
#    u'twitch': {u'name': u'cldly'}},
#   u'character': {u'class': u'Ranger',
#    u'experience': 56739,
#    u'level': 9,
#    u'name': u'cldly_'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 192},
#  {u'account': {u'challenges': {u'total': 25}, u'name': u'Cruella'},
#   u'character': {u'class': u'Witch',
#    u'experience': 55583,
#    u'level': 9,
#    u'name': u'ZooeyLateStart'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 193},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'Art3misia'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 55505,
#    u'level': 9,
#    u'name': u'vsfdxcvsfdx'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 194},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'hordwish'},
#   u'character': {u'class': u'Witch',
#    u'experience': 55252,
#    u'level': 9,
#    u'name': u'Whistity'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 195},
#  {u'account': {u'challenges': {u'total': 14}, u'name': u'mother_russia_'},
# ...
#    u'twitch': {u'name': u'olivetv'}},
#   u'character': {u'class': u'Shadow',
#    u'experience': 521,
#    u'level': 1,
#    u'name': u'hearthstonenobetaclub'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 479},
#  {u'account': {u'challenges': {u'total': 18},
#    u'name': u'tshern',
#    u'twitch': {u'name': u'khorus86'}},
#   u'character': {u'class': u'Marauder',
#    u'experience': 515,
#    u'level': 1,
#    u'name': u'Blargaghaodgh'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 480},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'diFFFerent'},
#   u'character': {u'class': u'Marauder',
#    u'experience': 504,
#    u'level': 1,
#    u'name': u'goess'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 481},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'420peace'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 497,
#    u'level': 1,
#    u'name': u'hmgcvbnkh'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 482},
#  {u'account': {u'challenges': {u'total': 13}, u'name': u'Clash710'},
#   u'character': {u'class': u'Witch',
#    u'experience': 421,
#    u'level': 1,
#    u'name': u'SwitchaWitch'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 483},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'klasmenos'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 387,
#    u'level': 1,
#    u'name': u'klasmenos'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 484},
#  {u'account': {u'challenges': {u'total': 11}, u'name': u'Pepasc'},
#   u'character': {u'class': u'Marauder',
#    u'experience': 374,
#    u'level': 1,
#    u'name': u'I_AM_A_WARRIOR_TOO'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 485},
#  {u'account': {u'challenges': {u'total': 8}, u'name': u'rubisko'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 335,
#    u'level': 1,
#    u'name': u'fefefqwqqqqqw'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 486},
#  {u'account': {u'challenges': {u'total': 0},
#    u'name': u'databomb',
#    u'twitch': {u'name': u'vpn_'}},
#   u'character': {u'class': u'Duelist',
#    u'experience': 326,
#    u'level': 1,
#    u'name': u'riiiiiiiiip'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 487},
#  {u'account': {u'challenges': {u'total': 19}, u'name': u'Tremers'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 317,
#    u'level': 1,
#    u'name': u'Aaron_Gootan'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 488},
#  {u'account': {u'challenges': {u'total': 0},
#    u'name': u'Lassittor',
#    u'twitch': {u'name': u'lassittor'}},
#   u'character': {u'class': u'Shadow',
#    u'experience': 300,
#    u'level': 1,
#    u'name': u'Lassitter'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 489},
#  {u'account': {u'challenges': {u'total': 0},
#    u'name': u'Repsi',
#    u'twitch': {u'name': u'tucnak2'}},
#   u'character': {u'class': u'Marauder',
#    u'experience': 281,
#    u'level': 1,
#    u'name': u'TucnakPEWPEW'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 490},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'corkros'},
#   u'character': {u'class': u'Templar',
#    u'experience': 276,
#    u'level': 1,
#    u'name': u'volsungana'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 491},
#  {u'account': {u'challenges': {u'total': 24}, u'name': u'Familiengrab'},
#   u'character': {u'class': u'Marauder',
#    u'experience': 246,
#    u'level': 1,
#    u'name': u'Drakonheart'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 492},
#  {u'account': {u'challenges': {u'total': 10}, u'name': u'cheefa'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 238,
#    u'level': 1,
#    u'name': u'raaaaaarepppppppp'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 493},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'Tatoolo'},
#   u'character': {u'class': u'Witch',
#    u'experience': 230,
#    u'level': 1,
#    u'name': u'TemplarsAreForJerks'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 494},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'Sat9'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 227,
#    u'level': 1,
#    u'name': u'HouseARRESTforlife'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 495},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'b100d'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 226,
#    u'level': 1,
#    u'name': u'is_this_descent'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 496},
#  {u'account': {u'challenges': {u'total': 0},
#    u'name': u'TeamApple',
#    u'twitch': {u'name': u'thebringerofra1n'}},
#   u'character': {u'class': u'Duelist',
#    u'experience': 224,
#    u'level': 1,
#    u'name': u'Dripparian'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 497},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'BR_RapTurE'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 209,
#    u'level': 1,
#    u'name': u'BrRapTurE'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 498},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'GamerBoiTester'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 195,
#    u'level': 1,
#    u'name': u'_AmITooLate'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 499},
#  {u'account': {u'challenges': {u'total': 25}, u'name': u'GasparTomas'},
#   u'character': {u'class': u'Witch',
#    u'experience': 193,
#    u'level': 1,
#    u'name': u'gadgregersg'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 500},
#  {u'account': {u'challenges': {u'total': 17}, u'name': u'Crissae'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 176,
#    u'level': 1,
#    u'name': u'Jyrnaloa'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 501},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'xdragonfireboix'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 175,
#    u'level': 1,
#    u'name': u'Spinnaroony'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 502},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'Tatoolo'},
#   u'character': {u'class': u'Marauder',
#    u'experience': 175,
#    u'level': 1,
#    u'name': u'trythatagain_dudes'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 503},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'kriganx'},
#   u'character': {u'class': u'Witch',
#    u'experience': 155,
#    u'level': 1,
#    u'name': u'krigt'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 504},
#  {u'account': {u'challenges': {u'total': 19}, u'name': u'nheowitzki'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 155,
#    u'level': 1,
#    u'name': u'alt_strat__'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 505},
#  {u'account': {u'challenges': {u'total': 14}, u'name': u'NeoElla'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 155,
#    u'level': 1,
#    u'name': u'sahdpartee'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 506},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'GRiMSKuLL'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 155,
#    u'level': 1,
#    u'name': u'AA_Gem'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 507},
#  {u'account': {u'challenges': {u'total': 12},
#    u'name': u'Geldric',
#    u'twitch': {u'name': u'geldricpoe'}},
#   u'character': {u'class': u'Shadow',
#    u'experience': 155,
#    u'level': 1,
#    u'name': u'Geldric_Delme_II'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 508},
#  {u'account': {u'challenges': {u'total': 0},
#    u'name': u'4EverLost',
#    u'twitch': {u'name': u'4everlost'}},
#   u'character': {u'class': u'Shadow',
#    u'experience': 155,
#    u'level': 1,
#    u'name': u'PackRat_I'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 509},
#  {u'account': {u'challenges': {u'total': 8}, u'name': u'kanguro'},
#   u'character': {u'class': u'Templar',
#    u'experience': 155,
#    u'level': 1,
#    u'name': u'KanguriereP'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 510},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'krackin13'},
#   u'character': {u'class': u'Templar',
#    u'experience': 155,
#    u'level': 1,
#    u'name': u'dyjdtyjdytjdtydj'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 511},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'RhioTre'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 155,
#    u'level': 1,
#    u'name': u'Shadow_The_Unexpected'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 512},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'349528'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 155,
#    u'level': 1,
#    u'name': u'jqjhzzzzzz'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 513},
#  {u'account': {u'challenges': {u'total': 9}, u'name': u'Pe4ceM4ker'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 155,
#    u'level': 1,
#    u'name': u'aaaaaaaaaaaaafefefefe'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 514},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'witch75'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 155,
#    u'level': 1,
#    u'name': u'MuleOfFuckingKalandra'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 515},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'AdanOfDarkmoon'},
#   u'character': {u'class': u'Templar',
#    u'experience': 155,
#    u'level': 1,
#    u'name': u'BrotherAlopecia'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 516},
#  {u'account': {u'challenges': {u'total': 36},
#    u'name': u'seepah',
#    u'twitch': {u'name': u'seepah'}},
#   u'character': {u'class': u'Duelist',
#    u'experience': 155,
#    u'level': 1,
#    u'name': u'seepah_altAI_desu'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 517},
#  {u'account': {u'challenges': {u'total': 40}, u'name': u'Leioblastus'},
#   u'character': {u'class': u'Templar',
#    u'experience': 155,
#    u'level': 1,
#    u'name': u'_mulitata'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 518},
#  {u'account': {u'challenges': {u'total': 6}, u'name': u'Karauna'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 155,
#    u'level': 1,
#    u'name': u'MacheteMule'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 519},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'skoek'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 155,
#    u'level': 1,
#    u'name': u'YHC'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 520},
#  {u'account': {u'challenges': {u'total': 0},
#    u'name': u'Repsi',
#    u'twitch': {u'name': u'tucnak2'}},
#   u'character': {u'class': u'Shadow',
#    u'experience': 155,
#    u'level': 1,
#    u'name': u'Mulingforhillcock'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 521},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'TenzoYamato'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 155,
#    u'level': 1,
#    u'name': u'fgjdfgjdfgjdfgjdf'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 522},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'Soulsniper'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 155,
#    u'level': 1,
#    u'name': u'eweeege'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 523},
#  {u'account': {u'challenges': {u'total': 19}, u'name': u'Tremers'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 148,
#    u'level': 1,
#    u'name': u'Aaron_Gootan'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 524},
#  {u'account': {u'challenges': {u'total': 40},
#    u'name': u'wormicek',
#    u'twitch': {u'name': u'wormicek456'}},
#   u'character': {u'class': u'Witch',
#    u'experience': 116,
#    u'level': 1,
#    u'name': u'wormissaa'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 525},
#  {u'account': {u'challenges': {u'total': 10}, u'name': u'ChucruttyHadeS'},
#   u'character': {u'class': u'Marauder',
#    u'experience': 100,
#    u'level': 1,
#    u'name': u'ORCtwoHand'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 526},
#  {u'account': {u'challenges': {u'total': 14}, u'name': u'Instinctts'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 74,
#    u'level': 1,
#    u'name': u'ripsticctsts'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 527},
#  {u'account': {u'challenges': {u'total': 6}, u'name': u'Szamanka'},
#   u'character': {u'class': u'Marauder',
#    u'experience': 18,
#    u'level': 1,
#    u'name': u'aaavcdfgh'},
#   u'dead': True,
#   u'online': False,
#   u'rank': 528},
#  {u'account': {u'challenges': {u'total': 37},
#    u'name': u'Vorpaxis',
#    u'twitch': {u'name': u'rpcallaway'}},
#   u'character': {u'class': u'Shadow',
#    u'experience': 18,
#    u'level': 1,
#    u'name': u'dewpdewpdewp'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 529},
#  {u'account': {u'challenges': {u'total': 27}, u'name': u'epp_'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 0,
#    u'level': 1,
#    u'name': u'BurningLesbian'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 530},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'Glandric'},
#   u'character': {u'class': u'Witch',
#    u'experience': 0,
#    u'level': 1,
#    u'name': u'KyehWark'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 531},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'r4nsom'},
#   u'character': {u'class': u'Marauder',
#    u'experience': 0,
#    u'level': 1,
#    u'name': u'dhdthdhjhdrhgdh'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 532},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'argie0126'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 0,
#    u'level': 1,
#    u'name': u'BloodFeear'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 533},
#  {u'account': {u'challenges': {u'total': 0},
#    u'name': u'Laturi',
#    u'twitch': {u'name': u'laturi'}},
#   u'character': {u'class': u'Duelist',
#    u'experience': 0,
#    u'level': 1,
#    u'name': u'grvmib'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 534},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'Drazzbad'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 0,
#    u'level': 1,
#    u'name': u'Lukkun'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 535},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'barb222'},
#   u'character': {u'class': u'Marauder',
#    u'experience': 0,
#    u'level': 1,
#    u'name': u'Headkrusherxx'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 536},
#  {u'account': {u'challenges': {u'total': 12}, u'name': u'goblyn'},
#   u'character': {u'class': u'Templar',
#    u'experience': 0,
#    u'level': 1,
#    u'name': u'old_man_running'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 537},
#  {u'account': {u'challenges': {u'total': 6}, u'name': u'Karauna'},
#   u'character': {u'class': u'Duelist',
#    u'experience': 0,
#    u'level': 1,
#    u'name': u'MacheteMulee'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 538},
#  {u'account': {u'challenges': {u'total': 6}, u'name': u'Karauna'},
#   u'character': {u'class': u'Templar',
#    u'experience': 0,
#    u'level': 1,
#    u'name': u'MacheteStevee'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 539},
#  {u'account': {u'challenges': {u'total': 0},
#    u'name': u'MrSelfDestruct',
#    u'twitch': {u'name': u'mr53lfd35truct'}},
#   u'character': {u'class': u'Duelist',
#    u'experience': 0,
#    u'level': 1,
#    u'name': u'fuckoffeventualydie'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 540},
#  {u'account': {u'challenges': {u'total': 24},
#    u'name': u'Bahriel',
#    u'twitch': {u'name': u'bahriel'}},
#   u'character': {u'class': u'Witch',
#    u'experience': 0,
#    u'level': 1,
#    u'name': u'AbyssalStorm'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 541},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'InvectA'},
#   u'character': {u'class': u'Witch',
#    u'experience': 0,
#    u'level': 1,
#    u'name': u'Yeonzu'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 542},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'Maxim_005'},
#   u'character': {u'class': u'Ranger',
#    u'experience': 0,
#    u'level': 1,
#    u'name': u'SitaBait'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 543},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'KingGreen'},
#   u'character': {u'class': u'Shadow',
#    u'experience': 0,
#    u'level': 1,
#    u'name': u'TheManThatSoldTheWorld'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 544},
#  {u'account': {u'challenges': {u'total': 0}, u'name': u'Poundtown4u'},
#   u'character': {u'class': u'Templar',
#    u'experience': 0,
#    u'level': 1,
#    u'name': u'cvcbcvbhhh'},
#   u'dead': False,
#   u'online': False,
#   u'rank': 545}]

# %%
conn.close()

# %%
# This checks the number of duplicates
c.execute('''
          SELECT * FROM ladders
          WHERE rowid NOT IN(
             SELECT  MIN(rowid)
             FROM    ladders
             GROUP BY id, account, twitch, challenges, character, rank, class, experience, dead
             );
          ''')
len(c.fetchall())
# Out:
# 324884

# %% [markdown]
# I had some some duplicate records in the ladders table (324884 to be exact). I removed them using the code below (don't forget to commit!).

# %%
c.execute('''
          DELETE FROM ladders
          WHERE rowid NOT IN(
             SELECT  MIN(rowid)
             FROM    ladders
             GROUP BY id, account, twitch, challenges, character, rank, class, experience, dead
             );
          ''')

# %%
conn.commit()
